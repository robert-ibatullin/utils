# %%
import numpy as np
from sklearn.datasets import make_classification

from plot_bivariate_distributions import plot_bivariate_distributions

# %%
# linear scale
X, y = make_classification(n_samples=1000, n_features=5, n_classes=2, random_state=0)
plot_bivariate_distributions(X, y, [0,1,2])

# %%
# log scale
X = 10**X
plot_bivariate_distributions(X, y, [0,1,2])
