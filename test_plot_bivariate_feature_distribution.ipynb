# %%
import numpy as np
from sklearn.datasets import make_classification

from plot_bivariate_distributions import plot_bivariate_distributions

# %%
X, y = make_classification(n_samples=100, n_features=20, n_classes=2, random_state=0)

# %%
# linear scale
plot_bivariate_distributions(X, y, list(range(12)))

# %%
# log scale
X = 10**X
plot_bivariate_distributions(X, y, [0,1,2])
