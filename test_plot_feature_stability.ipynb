# %%
# !python -m pip install numpy pandas matplotlib seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

from plot_feature_stability import plot_feature_stability

# %%
date_range = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')
feature_values = np.random.randint(0, 101, size=(len(date_range), 10))
feature_names = [f'Feature{i}' for i in range(10)]
df = pd.DataFrame(
    columns=feature_names, 
    data=feature_values
)
df['ReportDate'] = date_range

# %%
plot_feature_stability(df, feature_names)

# %%
plot_feature_stability(df, feature_names[:3])
